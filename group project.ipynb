# %%
from requests import get
import matplotlib.pyplot as plt
import pandas as pd
from API_KEY import API_KEY

#Search Result For United States 

url = "https://asos2.p.rapidapi.com/v2/auto-complete" #  changes based on route

headers = {
    "X-RapidAPI-Key": 'API_KEY',
    "X-RapidAPI-Host": "asos2.p.rapidapi.com"
}

def autocomplete_viz(search_term, store, country):

    querystring = {"q":search_term, "store": store,"country": country}

    autocomplete_response = get(url, headers=headers, params=querystring).json()
    
    suggestions = autocomplete_response["suggestionGroups"][0]["suggestions"]
    
    search_terms, number_results = [], []
    for suggestion in suggestions:
        search_terms.append(suggestion["searchTerm"])
        number_results.append(suggestion["numberOfResults"])
    
    plt.barh(search_terms, number_results)
    
    plt.title("Results for " + search_term)
    plt.xlabel("Results")
   
    us_search_result = pd.DataFrame({
                                    "Search Term": search_terms,
                                    "Number of Results": number_results
                                   })
    
    print(us_search_result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 from API_KEY import API_KEY
#       6 #Search Result For United States
#       8 url = "https://asos2.p.rapidapi.com/v2/auto-complete" #  changes based on route
#
# ModuleNotFoundError: No module named 'API_KEY'

# %%
 autocomplete_viz("animal", "US", "US")
# Out:
#            Search Term  Number of Results
# 0         animal print                847
# 1                anime               1113
# 2   animal print dress                340
# 3  animal print womens                801
# 4     animal print men                 50
# 5     animal print top                658
# 6   animal print shoes                  9
# 7   animal print skirt                 58
# 8   animal print pants                 34

# %%
autocomplete_viz("animal", "FR", "FR")
# Out:
#            Search Term  Number of Results
# 0  robe imprimé animal                388
# 1       imprimé animal               1081
# 2               animal               1211

# %%
autocomplete_viz("animal", "DE", "DE")
# Out:
#           Search Term  Number of Results
# 0        animal print                141
# 1         animalprint                262
# 2  kleid animal print                  1
# 3              animal                169

# %%
autocomplete_viz("animal", "IT", "IT")
# Out:
#                Search Term  Number of Results
# 0                animalier               1254
# 1        vestito animalier                418
# 2         scarpe animalier                 17
# 3        camicia animalier                162
# 4          gonna animalier                 91
# 5  vestito donna animalier                411
# 6      pantaloni animalier                 99
# 7    bluse donna animalier                139
# 8           animalier uomo                254

# %%
autocomplete_viz("animal", "ES", "ES")
# Out:
#                      Search Term  Number of Results
# 0                   animal print                  1
# 1       vestido estampado animal                385
# 2               estampado animal               1159
# 3  vestido midi estampado animal                141
# 4                         animal               1218

# %%
autocomplete_viz("animal", "AU", "AU")
# Out:
#           Search Term  Number of Results
# 0               anime               1462
# 1        animal print               1062
# 2  animal print dress                338
# 3  animal print pants                 48
# 4  animal print shirt                 12
# 5    animal print top                148
# 6  animal print skirt                 50

# %%
#https://www.statista.com/statistics/1112060/most-popular-fashion-items-worldwide/

#https://www.businessinsider.com/clothing-items-guys-should-have-before-30-2017-7#a-nice-blazer-to-add-some-variety-2

# %%
#jeans 
Jeans = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [6228, 12463, 9763, 12243, 9302, 6813]
                                   })
Jeans_DF = pd.DataFrame(Jeans)
    
plt.bar(Jeans_DF["Country"],Jeans_DF["Results"])
    
plt.title("Jeans Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#t- shirts
t_Shirts = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [12089, 30520, 27995, 19178, 12336, 32648]
                                   })
t_shirts_DF = pd.DataFrame(t_Shirts)
    
plt.bar(t_shirts_DF["Country"],t_shirts_DF["Results"],)
    
plt.title("T Shirts Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#sneakers
sneakers = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [3326,6899,5931,4839,4079,7779]
                                   })
sneakers_DF = pd.DataFrame(sneakers)
    
plt.bar(sneakers_DF["Country"],sneakers_DF["Results"],)
    
plt.title("Sneakers Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Sweaters

Sweaters = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [4115,2467,9504,8468,4419,546]
                                   })
Sweaters_DF = pd.DataFrame(Sweaters)
    
plt.bar(Sweaters_DF["Country"],Sweaters_DF["Results"])
    
plt.title("Sweaters Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Sweaters

Sweaters = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [4115,2467,9504,8468,4419,546]
                                   })
Sweaters_DF = pd.DataFrame(Sweaters)
    
plt.bar(Sweaters_DF["Country"],Sweaters_DF["Results"])
    
plt.title("Sweaters Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Leather

DF = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [7240,3650,1927,5660,4155,8394]
                                   })
final_DF = pd.DataFrame(DF)
    
plt.bar(final_DF["Country"],final_DF["Results"])
    
plt.title("Leather Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Cargo

DF = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [1233,1794,1653,1785,1447,1536]
                                   })
final_DF = pd.DataFrame(DF)
    
plt.bar(final_DF["Country"],final_DF["Results"])
    
plt.title("Cargo Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Overalls

DF = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [187,289,2767,4454,248,3033]
                                   })
final_DF = pd.DataFrame(DF)
    
plt.bar(final_DF["Country"],final_DF["Results"])
    
plt.title("Overalls Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#animal Print
DF = ({"Country": ["US","FR","DE","IT","AU","ES"],
          "Results": [852,1092,262,1247,2059,1144]
                                   })
final_DF = pd.DataFrame(DF)
    
plt.bar(final_DF["Country"],final_DF["Results"])
    
plt.title("Animal Print Results by Country")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Limitations 
# 1: Language - difference might mean different things. A style might not have a direct translation resulting in different search criteria.
# 2: Location - Depending on the location more warehouses might be available thus more options to the consumer in that country 
# 3: results - results vary each call. Could be a consequence of daily trends  

#Countries with deticated websites 
#The UK, US, France, Germany, Australia and Russia)

#Places where ASOS has fulfillment centers 
#https://www.asosplc.com/this-is-asos/our-footprint/
#https://merchants.glopal.com/en-us/blog/what-turned-asos-online-store-into-a-global-ecommerce-giant
